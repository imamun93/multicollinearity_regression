    Input:
        df: pandas DataFrame
        size: vertical and horizontal size of the plot'''

    corr = df.corr()
    fig, ax = plt.subplots(figsize=(size, size))
    ax.matshow(corr)
    plt.xticks(range(len(corr.columns)), corr.columns);
    plt.yticks(range(len(corr.columns)), corr.columns);

# %%
plot_corr(data)

# %%
abs(data.corr())
# Out:
#               Femoral Neck      %Fat  Weight kg  Activity    %Fat S  Weight S  \
# Femoral Neck      1.000000  0.455584   0.656793  0.161818  0.455584  0.656793
# %Fat              0.455584  1.000000   0.826715  0.022527  1.000000  0.826715
# Weight kg         0.656793  0.826715   1.000000  0.107668  0.826715  1.000000
# Activity          0.161818  0.022527   0.107668  1.000000  0.022527  0.107668
# %Fat S            0.455584  1.000000   0.826715  0.022527  1.000000  0.826715
# Weight S          0.656793  0.826715   1.000000  0.107668  0.826715  1.000000
# Activity S        0.161818  0.022527   0.107668  1.000000  0.022527  0.107668
#
#               Activity S
# Femoral Neck    0.161818
# %Fat            0.022527
# Weight kg       0.107668
# Activity        1.000000
# %Fat S          0.022527
# Weight S        0.107668
# Activity S      1.000000

# %% [markdown]
# Prepare for model

# %%
model= LinearRegression()

# %%
m= data.drop(['Femoral Neck'], axis=1)
w= data[['Femoral Neck']]

# %%
m.head()
# Out:
#    %Fat  Weight kg  Activity    %Fat S   Weight S   Activity S
# 0  25.3  52.163126   3508.44 -3.265217  -1.765066   946.450435
# 1  29.3  61.801965   2773.54  0.734783   7.873772   211.550435
# 2  37.7  93.440034   1738.97  9.134783  39.511842  -823.019565
# 3  32.8  59.874197   1665.29  4.234783   5.946005  -896.699565
# 4  24.6  50.348756   3982.95 -3.965217  -3.579436  1420.960435

# %%
w.shape
# Out:
# (92, 1)

# %%
X_train, X_test, y_train, y_test= train_test_split(m, w, test_size= 0.2, random_state= 14)

# %%
print('X_train: ',X_train)
print('X_test: ',X_test)
print('y_train: ',y_train)
print('y_test: ',y_test)
# Out:
# X_train:      %Fat  Weight kg  Activity     %Fat S   Weight S   Activity S
# 91  25.6  47.627202   2366.34  -2.965217  -6.300990  -195.649565
# 46  41.0  63.049344   1880.67  12.434783   9.121152  -681.319565
# 33  26.8  52.163126   3381.07  -1.765217  -1.765066   819.080435
# 51  36.4  54.431088   2187.21   7.834783   0.502896  -374.779565
# 29  28.3  46.720017   1580.64  -0.265217  -7.208175  -981.349565
# 8   24.0  53.977496   2823.68  -4.565217   0.049304   261.690435
# 42  31.9  33.565838   2060.48   3.334783 -20.362354  -501.509565
# 90  22.9  34.019430   2560.61  -5.665217 -19.908762    -1.379565
# 81  23.4  44.452055   2002.41  -5.165217  -9.476137  -559.579565
# 56  39.4  98.429551   1704.27  10.834783  44.501359  -857.719565
# 63  39.2  91.625665   1280.89  10.634783  37.697473 -1281.099565
# 34  17.8  34.586421   5153.57 -10.765217 -19.341772  2591.580435
# 49  27.8  56.812448   2558.81  -0.765217   2.884256    -3.179565
# 65  34.1  68.038860   3795.98   5.534783  14.110668  1233.990435
# 16  31.1  54.431088   2116.94   2.534783   0.502896  -445.049565
# 85  28.6  47.740600   2226.92   0.034783  -6.187592  -335.069565
# 38  20.8  37.648169   1665.29  -7.765217 -16.280023  -896.699565
# 66  39.9  84.368186   1974.92  11.334783  30.439994  -587.069565
# 36  16.8  34.926615   2031.51 -11.765217 -19.001577  -530.479565
# 2   37.7  93.440034   1738.97   9.134783  39.511842  -823.019565
# 72  26.4  54.884680   1421.96  -2.165217   0.956488 -1140.029565
# 62  35.8  53.750699   3188.11   7.234783  -0.177493   626.120435
# 84  19.2  40.823316   1721.39  -9.365217 -13.104876  -840.599565
# 82  29.5  43.544870   4080.04   0.934783 -10.383322  1518.050435
# 89  31.4  43.998463   2922.46   2.834783  -9.929729   360.470435
# 6   21.2  51.709534   3002.38  -7.365217  -2.218658   440.390435
# 24  22.5  49.441572   1349.81  -6.065217  -4.486620 -1212.179565
# 20  30.9  57.719633   5853.51   2.334783   3.791441  3291.520435
# 44  25.3  49.441572   1450.86  -3.265217  -4.486620 -1111.129565
# 75  29.4  49.101377   2775.67   0.834783  -4.826815   213.680435
# 35  27.4  56.699050   2446.40  -1.165217   2.770858  -115.589565
# 52  46.8  93.893627    824.25  18.234783  39.965435 -1737.739565
# 39  22.7  39.008946   2730.81  -5.865217 -14.919246   168.820435
# 23  24.4  48.307591   2145.35  -4.165217  -5.620601  -416.639565
# 57  24.8  51.596135   1827.86  -3.765217  -2.332057  -734.129565
# y_train:      Femoral Neck
# 91         0.735
# 46         0.815
# 33         0.782
# 51         0.762
# 29         0.800
# 8          0.853
# 42         0.558
# 90         0.622
# 81         0.856
# 56         1.010
# 63         0.980
# 34         0.681
# 49         0.745
# 65         0.849
# 16         0.863
# 85         0.740
# 38         0.690
# 66         0.973
# 87         0.633
# 14         0.738
# 55         1.008
# 3          0.757
# 60         1.027
# 21         0.735
# 73         0.752
# 15         0.894
# 48         0.815
# 74         0.747
# 69         0.843
# 13         0.729
# ..           ...
# 83         0.710
# 53         1.020
# 27         0.762
# 59         1.081
# 9          0.825
# 31         0.789
# 76         0.794
# 17         0.827
# 45         0.699
# 68         0.776
# 67         0.866
# 41         0.749
# 37         0.645
# 5          0.883
# 0          0.934
# 78         0.837
# 86         0.737
# 77         0.720
# 4          1.031
# 32         0.955
# 25         0.704
# 26         0.742
# 61         0.802
# 80         0.738
# 10         0.772
# 28         0.731
# 71         0.687
# 22         0.859
# 12         0.963
# 88         0.621
#
# [73 rows x 1 columns]
# y_test:      Femoral Neck
# 64         0.848
# 18         0.850
# 36         0.670
# 2          0.933
# 72         0.676
# 62         0.783
# 84         0.770
# 82         0.793
# 89         0.744
# 6          0.837
# 24         0.821
# 20         0.795
# 44         0.734
# 75         0.738
# 35         0.850
# 52         0.861
# 39         0.680
# 23         0.763
# 57         0.885

# %%
y_train.shape
# Out:
# (73, 1)

# %%
X_train.shape
# Out:
# (73, 6)

# %%
frames = [X_train]
train_data= pd.concat(frames)
train_data.shape
# Out:
# (73, 6)

# %%
y_test.shape
# Out:
# (19, 1)

# %%
X_test.shape
# Out:
# (19, 6)

# %%
X_train.shape
# Out:
# (73, 6)

# %%
X_train.head()
# Out:
#     %Fat  Weight kg  Activity     %Fat S  Weight S  Activity S
# 91  25.6  47.627202   2366.34  -2.965217 -6.300990 -195.649565
# 46  41.0  63.049344   1880.67  12.434783  9.121152 -681.319565
# 33  26.8  52.163126   3381.07  -1.765217 -1.765066  819.080435
# 51  36.4  54.431088   2187.21   7.834783  0.502896 -374.779565
# 29  28.3  46.720017   1580.64  -0.265217 -7.208175 -981.349565

# %%
X= X_train
y= y_train
model= sm.OLS(y, X).fit()
predictions= model.predict(X)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Femoral Neck   R-squared:                       0.533
# Model:                            OLS   Adj. R-squared:                  0.513
# Method:                 Least Squares   F-statistic:                     26.25
# Date:                Tue, 18 Jun 2019   Prob (F-statistic):           1.93e-11
# Time:                        14:43:01   Log-Likelihood:                 85.150
# No. Observations:                  73   AIC:                            -162.3
# Df Residuals:                      69   BIC:                            -153.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# %Fat          -0.0026      0.001     -2.181      0.033      -0.005      -0.000
# Weight kg      0.0035      0.001      6.409      0.000       0.002       0.005
# Activity       0.0003   8.18e-06     33.003      0.000       0.000       0.000
# %Fat S        -0.0026      0.001     -2.186      0.032      -0.005      -0.000
# Weight S       0.0035      0.001      6.389      0.000       0.002       0.005
# Activity S    -0.0002   1.26e-05    -19.288      0.000      -0.000      -0.000
# ==============================================================================
# Omnibus:                        3.737   Durbin-Watson:                   1.785
# Prob(Omnibus):                  0.154   Jarque-Bera (JB):                3.784
# Skew:                           0.156   Prob(JB):                        0.151
# Kurtosis:                       4.071   Cond. No.                     4.88e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.37e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
y.shape
# Out:
# (73, 1)

# %%
X.shape
# Out:
# (73, 6)

# %%
fig= plt.figure(figsize=(15,8))
fig= sm.graphics.plot_regress_exog(model, '%Fat', fig=fig)
plt.show()

# %%
fig= plt.figure(figsize=(15,8))
fig= sm.graphics.plot_regress_exog(model, '%Fat S', fig=fig)
plt.show()

# %%
fig= plt.figure(figsize=(15,8))
fig= sm.graphics.plot_regress_exog(model, 'Weight kg', fig=fig)
plt.show()

# %%
fig= plt.figure(figsize=(15,8))
fig= sm.graphics.plot_regress_exog(model, 'Weight S', fig=fig)
plt.show()

# %%
fig= plt.figure(figsize=(15,8))
fig= sm.graphics.plot_regress_exog(model, 'Activity', fig=fig)
plt.show()

# %%
fig= plt.figure(figsize=(15,8))
fig= sm.graphics.plot_regress_exog(model, 'Activity S', fig=fig)
plt.show()

# %%
y.shape
# Out:
# (73, 1)

# %%
X.shape
# Out:
# (73, 6)

# %%
model = ols("w~m", data).fit()

# %%
anova_results = anova_lm(model)
print('\nANOVA results')
print(anova_results)
# Out:
# ANOVA results
#             df    sum_sq   mean_sq          F        PR(>F)
# m          6.0  0.552366  0.092061  17.080597  5.452588e-13
# Residual  88.0  0.474302  0.005390        NaN           NaN

# %%
yVIF=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
xVIF= X.columns

# %%
train_data.round()
# Out:
#     %Fat  Weight kg  Activity  %Fat S  Weight S  Activity S
# 91  26.0       48.0    2366.0    -3.0      -6.0      -196.0
# 46  41.0       63.0    1881.0    12.0       9.0      -681.0
# 33  27.0       52.0    3381.0    -2.0      -2.0       819.0
# 51  36.0       54.0    2187.0     8.0       1.0      -375.0
# 29  28.0       47.0    1581.0    -0.0      -7.0      -981.0
# 8   24.0       54.0    2824.0    -5.0       0.0       262.0
# 42  32.0       34.0    2060.0     3.0     -20.0      -502.0
# 90  23.0       34.0    2561.0    -6.0     -20.0        -1.0
# 81  23.0       44.0    2002.0    -5.0      -9.0      -560.0
# 56  39.0       98.0    1704.0    11.0      45.0      -858.0
# 63  39.0       92.0    1281.0    11.0      38.0     -1281.0
anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/Iffy/anaconda3/lib/python3.6/site-packages/statsmodels/stats/outliers_influence.py:181: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# %Fat          inf
# Weight kg     inf
# Activity      inf
# %Fat S        inf
# Weight S      inf
# Activity S    inf
# dtype: float64

# %%
X = data.assign(const=1)
>>> pd.Series([variance_inflation_factor(X.values, i) 
               for i in range(X.shape[1])], 
              index=X.columns)
# Out:
# /Users/Iffy/anaconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1543: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# Femoral Neck    2.08378
# %Fat                inf
# Weight kg           inf
# Activity            inf
# %Fat S              inf
# Weight S            inf
# Activity S          inf
# const           0.00000
# dtype: float64

# %%
df_cor = data.corr()
df_cor
# Out:
#               Femoral Neck      %Fat  Weight kg  Activity    %Fat S  Weight S  \
# Femoral Neck      1.000000  0.455584   0.656793  0.161818  0.455584  0.656793
# %Fat              0.455584  1.000000   0.826715 -0.022527  1.000000  0.826715
# Weight kg         0.656793  0.826715   1.000000 -0.107668  0.826715  1.000000
# Activity          0.161818 -0.022527  -0.107668  1.000000 -0.022527 -0.107668
# %Fat S            0.455584  1.000000   0.826715 -0.022527  1.000000  0.826715
# Weight S          0.656793  0.826715   1.000000 -0.107668  0.826715  1.000000
# Activity S        0.161818 -0.022527  -0.107668  1.000000 -0.022527 -0.107668
#
#               Activity S
# Femoral Neck    0.161818
# %Fat           -0.022527
# Weight kg      -0.107668
# Activity        1.000000
# %Fat S         -0.022527
# Weight S       -0.107668
# Activity S      1.000000

# %%
vif3=np.linalg.inv(df.corr().values)
vif3
# Out:
# array([[ 22.95      ,   6.45368112, -16.30191707,  -6.45368112],
#        [  6.45368112,   3.        ,  -4.08044115,  -2.        ],
#        [-16.30191707,  -4.08044115,  12.95      ,   4.08044115],
#        [ -6.45368112,  -2.        ,   4.08044115,   3.        ]])

# %%
newdata=pd.DataFrame(vif3, )
# Out:
#            0         1          2         3
# 0  22.950000  6.453681 -16.301917 -6.453681
# 1   6.453681  3.000000  -4.080441 -2.000000
# 2 -16.301917 -4.080441  12.950000  4.080441
# 3  -6.453681 -2.000000   4.080441  3.000000

# %%
pd.DataFrame(np.linalg.inv(df.corr().values), index = df_cor.index, columns=df_cor.columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1650                 blocks = [make_block(values=blocks[0],
# -> 1651                                      placement=slice(0, len(axes[0])))]
#    1652
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3094
# -> 3095     return klass(values, ndim=ndim, placement=placement)
#    3096
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals/blocks.py in __init__(self, values, placement, ndim)
#      86                 'Wrong number of items passed {val}, placement implies '
# ---> 87                 '{mgr}'.format(val=len(self.values), mgr=len(self.mgr_locs)))
#      88
#
# ValueError: Wrong number of items passed 4, placement implies 7
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-189-852c5dd507e8> in <module>
# ----> 1 pd.DataFrame(np.linalg.inv(df.corr().values), index = df_cor.index, columns=df_cor.columns)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     422             else:
#     423                 mgr = init_ndarray(data, index, columns, dtype=dtype,
# --> 424                                    copy=copy)
#     425
#     426         # For data is list-like, or Iterable (will consume into list)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals/construction.py in init_ndarray(values, index, columns, dtype, copy)
#     165         values = maybe_infer_to_datetimelike(values)
#     166
# --> 167     return create_block_manager_from_blocks([values], [columns, index])
#     168
#     169
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1658         blocks = [getattr(b, 'values', b) for b in blocks]
#    1659         tot_items = sum(b.shape[0] for b in blocks)
# -> 1660         construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    1661
#    1662
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals/managers.py in construction_error(tot_items, block_shape, axes, e)
#    1689         raise ValueError("Empty data passed with indices specified.")
#    1690     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 1691         passed, implied))
#    1692
#    1693
#
# ValueError: Shape of passed values is (4, 4), indices imply (7, 7)
